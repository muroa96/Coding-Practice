# %% [markdown]
# 코드업 100제

# %%
#6001
print("Hello")
# Out:
# Hello

# %%
#6002
print("Hello World")
# Out:
# Hello World

# %%
#6003
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
#6004
print("'Hello'")
# Out:
# 'Hello'

# %%
#6005
print('"Hello World"')
# Out:
# "Hello World"

# %%
#6006
print('\"!@#$%^&*()\'')
# Out:
# "!@#$%^&*()'

# %%
#6007
print('\"C:\\Download\\\'hello\'.py\"')
# Out:
# "C:\Download\'hello'.py"

# %%
#6008
print('print("Hello\\nWorld")')
# Out:
# print("Hello\nWorld")

# %%
#6009
c = input()
print(c)
# Out:
# aa
# aa

# %%
#6010
n = input()
n = int(n)
print(n)
# Out:
# 5
# 5

# %%
#6011
x = input()
x = float(x)
print(x)
# Out:
# 2.2
# 2.2

# %%
#6012
x= input()
y = input()
print(x)
print(y)
# Out:
# 1
# 2
# 1
# 2

# %%
#6013
a = input()
b = input()

print(b)
print(a)
# Out:
# 1
# 2
# 2
# 1

# %%
#6014
x = input()

print(x)
print(x)
print(x)
# Out:
# 0.1
# 0.1
# 0.1
# 0.1

# %%
#6015
a, b = input().split()
print(a)
print(b)
# Out:
# 1 2
# 1
# 2

# %%
#6016
a, b = input().split()
print(b, a)
# Out:
# 2 3
# 3 2

# %%
print('\"!@#$%^&*()\'')
# Out:
# "!@#$%^&*()'
